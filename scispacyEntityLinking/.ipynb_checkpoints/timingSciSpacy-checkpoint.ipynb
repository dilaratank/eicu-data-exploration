# %% [markdown]
# # Timing SciSpacy

# %%
import argparse
import spacy
import scispacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.linking import EntityLinker
import en_ner_bc5cdr_md # make sure you download the model with pip install pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bc5cdr_md-0.5.1.tar.gz
import pandas as pd
import warnings
import gc
from tqdm.notebook import tqdm

# %%
kaggle_patient_notes = pd.read_csv('/home/dtank/data/volume_2/eicu_csv/patient_notes.csv')
kaggle_patient_notes_df = kaggle_patient_notes[:1150] # make a dataframe (42146 rows)

kaggle_patient_notes_str = '; '.join(kaggle_patient_notes_df['pn_history'].tolist()) # make a string

def scispacy_pipeline_df(df, column_name):
    # set environment
    spacy.require_gpu()
    print('gpu enabled')
    warnings.filterwarnings("ignore")
    print('warnings ignored')
    
    # create nlp environment
    nlp = en_ner_bc5cdr_md.load()
    nlp.add_pipe("abbreviation_detector")
    config = {
        "k": 10,
        "resolve_abbreviations": True,
        "linker_name": "umls",
        "max_entities_per_mention": 1
    }
    nlp.add_pipe("scispacy_linker", config=config)
    linker =  nlp.get_pipe("scispacy_linker")
    print('nlp environment set')
    
    # perform entity linking
    for i, sentence in enumerate(tqdm(df[column_name])):
        try:
            note = nlp(sentence)
        except:
            continue
            
        ents = []
        labels = []
        cuis = []
        linked_ent_names = []
            
        for entity in note.ents:
            ents.append(entity.text)
            labels.append(entity.label_)

            for linker_ent in entity._.kb_ents:
                cuis.append(linker.kb.cui_to_entity[linker_ent[0]][0])
                linked_ent_names.append(linker.kb.cui_to_entity[linker_ent[0]][1])
                
        df['entities'] = ', '.join(ents)
        df['labels'] = ', '.join(labels)
        df['cuis'] = ', '.join(cuis)
        df['linked_ent_names'] = ', '.join(linked_ent_names)
    
    return 

def scispacy_pipeline_str(note_str):
    # set environment
    spacy.require_gpu()
    print('gpu enabled')
    warnings.filterwarnings("ignore")
    print('warnings ignored')
    
    # create nlp environment
    nlp = en_ner_bc5cdr_md.load()
    nlp.add_pipe("abbreviation_detector")
    config = {
        "k": 10,
        "resolve_abbreviations": True,
        "linker_name": "umls",
        "max_entities_per_mention": 1
    }
    nlp.add_pipe("scispacy_linker", config=config)
    linker =  nlp.get_pipe("scispacy_linker")
    print('nlp environment set')
    
    # perform entity linking
    note = nlp(note_str)
    
    ents = []
    labels = []
    cuis = []
    linked_ent_names = []
    
    for entity in note.ents:
            ents.append(entity.text)
            labels.append(entity.label_)

            for linker_ent in entity._.kb_ents:
                cuis.append(linker.kb.cui_to_entity[linker_ent[0]][0])
                linked_ent_names.append(linker.kb.cui_to_entity[linker_ent[0]][1])
    
    return ents, labels, cuis, linked_ent_names

# %%
# %%time
scispacy_pipeline_df(kaggle_patient_notes_df, 'pn_history')
# Out:
# gpu enabled
# warnings ignored
# nlp environment set
#   0%|          | 0/1150 [00:00<?, ?it/s]
# CPU times: user 2min 2s, sys: 4.36 s, total: 2min 7s
# Wall time: 1min 58s

# %%
# Text of length 34567170 exceeds maximum of 1.000.000.
# The parser and NER models require roughly 1GB of temporary memory per 100,000 characters in the input. 
# This means long texts may cause memory allocation errors. If you're not using the parser or NER, 
# it's probably safe to increase the `nlp.max_length` limit. The limit is in number of characters, 
# so you can check whether your inputs are too long by checking `len(text)`.

# %%
# %%time
ents, labels, cuis, linked_ent_names = scispacy_pipeline_str(kaggle_patient_notes_str)
# Out:
# gpu enabled
# warnings ignored
# nlp environment set
# CPU times: user 2min 1s, sys: 6.56 s, total: 2min 7s
# Wall time: 1min 58s

# %%
kaggle_patient_notes_df
# Out:
#       pn_num  case_num                                         pn_history  \
# 0          0         0  17-year-old male, has come to the student heal...
# 1          1         0  17 yo male with recurrent palpitations for the...
# 2          2         0  Dillon Cleveland is a 17 y.o. male patient wit...
# 3          3         0  a 17 yo m c/o palpitation started 3 mos ago; \...
# 4          4         0  17yo male with no pmh here for evaluation of p...
# ...      ...       ...                                                ...
# 1145    1228         0  HPI: 17 yo M, presenting with paplitation sinc...
# 1146    1229         0  Dillon Cleveland is 17 yo M who presents with ...
# 1147    1230         0  17 YO M WITH PALPITATIONS SINCE A FEW MONTHS A...
# 1148    1231         0  CC: Mr. Cleveland is a 17yoM p/w multiple epis...
# 1149    1232         0  Dillion Cleveland 17 year old with no signific...
#
#                                                entities  \
# 0     -heart pounding, + palpitations\r\n, SOB, whee...
# 1     -heart pounding, + palpitations\r\n, SOB, whee...
# 2     -heart pounding, + palpitations\r\n, SOB, whee...
# 3     -heart pounding, + palpitations\r\n, SOB, whee...
# 4     -heart pounding, + palpitations\r\n, SOB, whee...
# ...                                                 ...
# 1145  -heart pounding, + palpitations\r\n, SOB, whee...
# 1146  -heart pounding, + palpitations\r\n, SOB, whee...
# 1147  -heart pounding, + palpitations\r\n, SOB, whee...
# 1148  -heart pounding, + palpitations\r\n, SOB, whee...
# 1149  -heart pounding, + palpitations\r\n, SOB, whee...
#
#                                                  labels  \
# 0     DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 1     DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 2     DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 3     DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 4     DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# ...                                                 ...
# 1145  DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 1146  DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 1147  DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 1148  DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
# 1149  DISEASE, DISEASE, DISEASE, DISEASE, DISEASE, D...
#
#                                                    cuis  \
# 0     C0030252, C0013404, C0043144, C0085619, C00186...
# 1     C0030252, C0013404, C0043144, C0085619, C00186...
# 2     C0030252, C0013404, C0043144, C0085619, C00186...
# 3     C0030252, C0013404, C0043144, C0085619, C00186...
# 4     C0030252, C0013404, C0043144, C0085619, C00186...
# ...                                                 ...
# 1145  C0030252, C0013404, C0043144, C0085619, C00186...
# 1146  C0030252, C0013404, C0043144, C0085619, C00186...
# 1147  C0030252, C0013404, C0043144, C0085619, C00186...
# 1148  C0030252, C0013404, C0043144, C0085619, C00186...
# 1149  C0030252, C0013404, C0043144, C0085619, C00186...
#
#                                        linked_ent_names
# 0     Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 1     Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 2     Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 3     Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 4     Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# ...                                                 ...
# 1145  Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 1146  Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 1147  Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 1148  Palpitations, Dyspnea, Wheezing, Orthopnea, He...
# 1149  Palpitations, Dyspnea, Wheezing, Orthopnea, He...
#
# [1150 rows x 7 columns]

# %%
print(ents)
print()
print(labels)
print()
print(cuis)
print()
print(linked_ent_names)
# Out:
# ['heart pounding', 'dispnea', 'chest pain', 'chills', 'fever', 'nausea', 'vomiting', 'palpitations', 'durign', 'headedness', 'diarrhea', 'complaints of heart pounding', 'pain', 'lightheadedness', 'shortness of breath', 'pounding', 'shortness of breath', 'chest pain', 'anxiety', 'thyroid disease', 'palpitation', 'CAN', 'NO', 'palpitations', 'weight loss', 'fevers', 'PSH', 'FHX', 'thyroid disorder', 'SHX', 'ETOH', 'shortness of breath', 'lightheadedness', 'diaphoresis', 'vomiting', 'tremor', 'loss of consciousness\r\nNo fever', 'nausea', 'vomiting', 'diarrhea', 'rash', 'anxiety', 'palpitations', 'Allergies', 'Adderall', 'cocaine', 'thyroid disease', 'heart pounding', 'shortness of breath', 'fever', 'weight loss', 'Alcohol', 'Adderall', 'Allergies', 'episodic pounding heart', 'Denies syncope', 'lightheadedness', 'heart palpitations', 'SOB', 'cough', 'swelling', 'dizziness', 'pain', 'fever', 'Allergies', 'etOH', 'palpitations', 'palpitations', 'Palpitations', 'palpitations', 'palpitations', 'SOB', 'presyncope', 'palpitations', 'thyroid disorder', 'palpitations', 'chest pain', 'diaphoresis', 'shortness of breath', 'palpitations', 'loss of consciousness', 'Adderall', 'caffeine', 'Adderall', 'Hyperthyroidism', 'drins', 'heart pounding', 'Weight gain', 'Allergies', 'arrythmias', 'alcohol', 'pounding', 'heart pounding', 'shortness of breath', 'lightheadedness', 'nausea', 'numbness', 'Allergies', 'alcohol', 'cannabis', 'heart pounding', 'nausea', 'vomiting', 'anxiety', 'shortness of breath', 'dizzyness', 'allergies', 'alcohol', 'shortness of breath', 'cough', 'intermittent palpitations', 'shortness of breath', 'chest pain', 'alcohol', 'heart pounding', 'heart pounding', 'SOB', 'lightheadedness', 'epidose', 'allergies', 'cardiac death', 'NO', 'anxiety', 'Palpitations', 'SOB', 'lightheadedness', 'headaches', 'weight loss', 'nausea vomiting', 'abdominal pain', 'palpitations', 'Denies shortness of breath', 'diaphoresis', 'fevers', 'chills', 'headache', 'fatigue', 'vision/hearing', 'thyroid disease', 'pounding', 'chest pain', 'SOB', 'headedness', 'PMH-none', 'palpitations', 'heart pounding', 'dizziness', 'anxiety', 'fevers', 'chills', 'weight loss', 'diaphoresis', 'caffeine', 'Adderall', 'alcohol', 'hyperthyroid', 'deaths', 'heart palpitations', 'heart pounding', 'heart palpitations', 'SOB', 'Adderall', 'weight loss', 'diarrhea', 'anxiety', 'bloody urine/stool', 'thyroid disease', 'alcohol', 'heart palpitations', 'pounding', 'SOB', 'lightheadedness', 'Ativan', 'Aslo', 'fevers', 'chills', 'cough', 'N/V', 'pain', 'constipation', 'diarrhea', 'Ativan', 'CC', 'heart palpitations', 'Pt', 'All-', 'alcohol', 'Drugs-', 'shortness of breath', 'palpitations', 'palpitation', 'chest pain', 'dyspnea', 'fever', 'fatique', 'anorexia', 'cough', 'wheezing', 'CC', 'trauma', 'EtOH', 'episodic palpitations', 'lightheadedness', 'SOB', 'chest pain', 'headaches', 'fevers', 'chills', 'nausea', 'vomiting', 'heart punding', 'caffeine', 'dizziness', 'gait problems', 'tremors', 'weight loss', 'Allergy', 'Pain', 'palpitations', 'heart pounding', 'pain', 'fevers', 'chills', 'cough', 'abdominal pain', 'headaches', 'Allergies', 'ETOH', 'chest pain', 'SOB', 'fever', 'sweats', 'chills', 'abdominal pain', 'Adarol', 'thyroid disease', 'pounding', 'pounding', 'syncope', 'elevated anxiety', 'weight loss', 'weight gain', 'Allergies', 'Adderall', 'arrythmias', 'CC', 'pain', 'allergies', 'ROS', 'shortness of breath', 'headaches', 'chest pain', 'fever', 'chills', 'anxiety', 'depression', 'alcohol', 'pounding', 'Pt', 'SOB', 'Denies extremity pain', 'weakness', 'diaphoresis', 'headache', 'dizziness', 'vomit', 'nausea', 'ALL', 'Dx', 'palpitations', 'Pt', 'diaphoresis', 'SOB', 'cough', 'nausea', 'vomiting', 'fever', 'appetite or weight loss', 'Thyroid disease', 'heart pounding', 'SOB', 'arrythmia', 'cardiac death', 'heart palpitations', 'shortness of breath', 'diaphoresis', 'diarrhea', 'weight loss', 'fever chills', 'abdominal pain', 'anciteyt', 'allergies', 'lightheadedness', 'chest pai ...
#
# ['DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'CHEMICAL', 'CHEMICAL', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 'DISEASE', 
art', 'Nausea', 'Vomiting', 'Anxiety', 'Dyspnea', 'Dizziness', 'Hypersensitivity', 'ethanol', 'Dyspnea', 'Coughing', 'Intermittent palpitations', 'Dyspnea', 'Chest Pain', 'ethanol', 'Pounding heart', 'Pounding heart', 'Dyspnea', 'Dizziness', 'Hypersensitivity', 'Cardiac Death', 'nitric oxide', 'Anxiety', 'Palpitations', 'Dyspnea', 'Dizziness', 'Headache', 'Weight decreased', 'Nausea and vomiting', 'Abdominal Pain', 'Palpitations', 'Dyspnea', 'Increased sweating', 'Fever', 'Chills', 'Headache', 'Fatigue', 'Thyroid Diseases', 'Pounds', 'Chest Pain', 'Dyspnea', 'Lightheadedness', 'Palpitations', 'Pounding heart', 'Dizziness', 'Anxiety', 'Fever', 'Chills', 'Weight decreased', 'Increased sweating', 'caffeine', 'Adderall', 'ethanol', 'Hyperthyroidism', 'Cessation of life', 'Palpitations', 'Pounding heart', 'Palpitations', 'Dyspnea', 'Adderall', 'Weight decreased', 'Diarrhea', 'Anxiety', 'Hematochezia', 'Thyroid Diseases', 'ethanol', 'Palpitations', 'Pounds', 'Dyspnea', 'Dizziness', 'Ativan', 'Fever', 'Chills', 'Coughing', 'Pain', 'Constipation', 'Diarrhea', 'Ativan', 'cholecalciferol', 'Palpitations', 'Patients', 'ethanol', 'Dyspnea', 'Palpitations', 'Palpitations', 'Chest Pain', 'Dyspnea', 'Fever', 'Anorexia', 'Coughing', 'Wheezing', 'cholecalciferol', 'Wounds and Injuries', 'ethanol', 'Palpitations', 'Dizziness', 'Dyspnea', 'Chest Pain', 'Headache', 'Fever', 'Chills', 'Nausea', 'Vomiting', 'caffeine', 'Dizziness', 'Gait abnormality', 'Tremor', 'Weight decreased', 'Allergy Specialty', 'Pain', 'Palpitations', 'Pounding heart', 'Pain', 'Fever', 'Chills', 'Coughing', 'Abdominal Pain', 'Headache', 'Hypersensitivity', 'ethanol', 'Chest Pain', 'Dyspnea', 'Fever', 'Sweat', 'Chills', 'Abdominal Pain', 'Thyroid Diseases', 'Pounds', 'Pounds', 'Syncope', 'Weight decreased', 'Weight Gain', 'Hypersensitivity', 'Adderall', 'Cardiac Arrhythmia', 'cholecalciferol', 'Pain', 'Hypersensitivity', 'Reactive Oxygen Species', 'Dyspnea', 'Headache', 'Chest Pain', 'Fever', 'Chills', 'Anxiety', 'Mental Depression', 'ethanol', 'Pounds', 'Patients', 'Dyspnea', 'Pain in limb', 'Weakness', 'Increased sweating', 'Headache', 'Dizziness', 'Vomiting', 'Nausea', 'Acute lymphocytic leukemia', 'Diagnosis', 'Palpitations', 'Patients', 'Increased sweating', 'Dyspnea', 'Coughing', 'Nausea', 'Vomiting', 'Fever', 'Anorexia', 'Thyroid Diseases', 'Pounding heart', 'Dyspnea', 'Cardiac Arrhythmia', 'Cardiac Death', 'Palpitations', 'Dyspnea', 'Increased sweating', 'Diarrhea', 'Weight decreased', 'Fever with chills', 'Abdominal Pain', 'Hypersensitivity', 'Dizziness', 'Chest Pain', 'Dyspnea', 'Headache', 'Nausea', 'Vomiting', 'cocaine', 'Hypersensitivity', 'Palpitations', 'Palpit ...
